# %% [markdown]
# <a href="https://colab.research.google.com/github/usmantakai/ai-renewable-energy-projects/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
np.random.seed(42)
data = {
    "temperature": np.random.randint(20, 40, 100),
    "humidity": np.random.randint(30, 90, 100),
    "energy_consumption":
    np.random.randint(200, 600, 100)
}
df = pd.DataFrame(data)
df.head()
# Out:
#    temperature  humidity  energy_consumption
# 0           26        64                 494
# 1           39        73                 585
# 2           34        69                 586
# 3           30        51                 312
# 4           27        56                 300

# %%
x = df[['temperature', 'humidity']]
y = df['energy_consumption']

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3448968762.py in <cell line: 0>()
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(
#       2     x, y, test_size=0.2, random_state=42
#       3 )
#
# NameError: name 'train_test_split' is not defined

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R2 Score:", r2)
# Out:
# Mean Squared Error: 12193.729788080793
# R2 Score: -0.04507643699208552

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.plot(y_test.values[:200], label="Actual")
plt.plot(y_pred[:200], label="predicted")
plt.legend()
plt.title("Electricity Load Forecasting")
plt.xlabel("Time")
plt.ylabel("Power Consumption")
plt.show()

# %%
df['Data'] = pd.to_datetime(df['Data'],
              errors='coerce')
df = df.dropna()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2002719358.py in <cell line: 0>()
# ----> 1 df['Data'] = pd.to_datetime(df['Data'],
# ...
