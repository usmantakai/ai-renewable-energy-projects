# %% [markdown]
# <a href="https://colab.research.google.com/github/usmantakai/ai-renewable-energy-projects/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solar Energy Forecasting
# This notebook explores basic steps toward forecasting solar energy generation using machine learning.

# %%
print("Notebook initialized successfully")
# Out:
# Notebook initialized successfully
