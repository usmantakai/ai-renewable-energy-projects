# %% [markdown]
# <a href="https://colab.research.google.com/github/usmantakai/ai-renewable-energy-projects/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solar Energy Forecasting Using Machine Learning
# ## Aim
# To develop a ML model for forecasting solar energy generation using historical time-series data.
# ## Motivation
# Accurate solar energy forecasting is critical for grid stability, energy planning, and effective integration of renewable energy sources.
# ## Scope
# This notebook covers data loading, exploratory data analysis, feature engineering, model training, and performance evaluation.

# %%
# Environment setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
plt.style.use("default")
print("Environment setup complete")
# Out:
# Environment setup complete

# %% [markdown]
# ## Data Description
# The dataset contains historical solar power generation values recorded at regular time intervals.

# %%
# Create a synthetic solar energy dataset
np.random.seed(42)
hours = 500
time_index = pd.data_range("2024-01-01", periods=hours, freq="H")
power = (
    np.maximum(0, np.sin(np.linspace(0, 20, hours))) * 50 + np.random.normal(0, 5, hours)
)
data = pd.DataFrame({"timestamp": time_index, "power": power
                     })
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-400656481.py in <cell line: 0>()
#       2 np.random.seed(42)
#       3 hours = 500
# ----> 4 time_index = pd.data_range("2024-01-01", periods=hours, freq="H")
#       5 power = (
#       6     np.maximum(0, np.sin(np.linspace(0, 20, hours))) * 50 + np.random.normal(0, 5, hours)
#
# AttributeError: module 'pandas' has no attribute 'data_range'
